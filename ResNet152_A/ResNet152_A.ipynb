# %%
# !python main.py
# Out:
# ==> Preparing data..
# ...
# 100%|███████████████████████| 170498071/170498071 [00:11<00:00, 14300123.09it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 20, 32, 32]             540
#        BatchNorm2d-2           [-1, 20, 32, 32]              40
#             Conv2d-3           [-1, 20, 32, 32]             400
#        BatchNorm2d-4           [-1, 20, 32, 32]              40
#             Conv2d-5           [-1, 20, 32, 32]           3,600
#        BatchNorm2d-6           [-1, 20, 32, 32]              40
#             Conv2d-7           [-1, 60, 32, 32]           1,200
#        BatchNorm2d-8           [-1, 60, 32, 32]             120
#             Conv2d-9           [-1, 60, 32, 32]           1,200
# ...
