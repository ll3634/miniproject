# %%
# !python main.py
# Out:
# ==> Preparing data..
# ...
# 100%|███████████████████████| 170498071/170498071 [00:02<00:00, 58662408.02it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 15, 32, 32]             405
#        BatchNorm2d-2           [-1, 15, 32, 32]              30
#             Conv2d-3           [-1, 15, 32, 32]             225
#        BatchNorm2d-4           [-1, 15, 32, 32]              30
#             Conv2d-5           [-1, 15, 32, 32]           2,025
#        BatchNorm2d-6           [-1, 15, 32, 32]              30
#             Conv2d-7           [-1, 60, 32, 32]             900
#        BatchNorm2d-8           [-1, 60, 32, 32]             120
#             Conv2d-9           [-1, 60, 32, 32]           8,100
# ...
