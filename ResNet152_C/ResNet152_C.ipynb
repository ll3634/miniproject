# %%
# !python main.py
# Out:
# ==> Preparing data..
# ...
# 100%|██████████████████████| 170498071/170498071 [00:01<00:00, 100187822.72it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 11, 32, 32]             297
#        BatchNorm2d-2           [-1, 11, 32, 32]              22
#             Conv2d-3           [-1, 11, 32, 32]             121
#        BatchNorm2d-4           [-1, 11, 32, 32]              22
#             Conv2d-5           [-1, 11, 32, 32]           1,089
#        BatchNorm2d-6           [-1, 11, 32, 32]              22
#             Conv2d-7           [-1, 44, 32, 32]             484
#        BatchNorm2d-8           [-1, 44, 32, 32]              88
#             Conv2d-9           [-1, 44, 32, 32]           4,356
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

with open('acc_ResNet152_C.txt','r')as f:
    acc_ResNet152_C = f.readlines()
    acc_ResNet152_C = [i.replace('\n','') for i in acc_ResNet152_C]
    acc_ResNet152_C = np.array(acc_ResNet152_C,dtype=float)

plt.figure()
plt.plot(acc_ResNet152_C,label='ResNet-152-C')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
