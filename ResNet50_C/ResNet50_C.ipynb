# %%
# !python main.py
# Out:
# ==> Preparing data..
# ...
# 100%|███████████████████████| 170498071/170498071 [00:01<00:00, 91280570.31it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 15, 32, 32]             405
#        BatchNorm2d-2           [-1, 15, 32, 32]              30
#             Conv2d-3           [-1, 15, 32, 32]             225
#        BatchNorm2d-4           [-1, 15, 32, 32]              30
#             Conv2d-5           [-1, 15, 32, 32]           2,025
#        BatchNorm2d-6           [-1, 15, 32, 32]              30
#             Conv2d-7           [-1, 60, 32, 32]             900
#        BatchNorm2d-8           [-1, 60, 32, 32]             120
#             Conv2d-9           [-1, 60, 32, 32]             900
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

with open('acc_ResNet50_C.txt','r')as f:
    acc_ResNet50_C = f.readlines()
    acc_ResNet50_C = [i.replace('\n','') for i in acc_ResNet50_C]
    acc_ResNet50_C = np.array(acc_ResNet50_C,dtype=float)

plt.figure()
plt.plot(acc_ResNet50_C,label='ResNet-50-C')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
