# %%
# !python main.py
# Out:
# ==> Preparing data..
# ...
# 100%|███████████████████████| 170498071/170498071 [00:02<00:00, 75083676.99it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 21, 32, 32]             567
#        BatchNorm2d-2           [-1, 21, 32, 32]              42
#             Conv2d-3           [-1, 21, 32, 32]             441
#        BatchNorm2d-4           [-1, 21, 32, 32]              42
#             Conv2d-5           [-1, 21, 32, 32]           3,969
#        BatchNorm2d-6           [-1, 21, 32, 32]              42
#             Conv2d-7           [-1, 84, 32, 32]           1,764
#        BatchNorm2d-8           [-1, 84, 32, 32]             168
#             Conv2d-9           [-1, 84, 32, 32]          15,876
# ...

# %%
# !python main_acc_test.py
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 21, 32, 32]             567
#        BatchNorm2d-2           [-1, 21, 32, 32]              42
#             Conv2d-3           [-1, 21, 32, 32]             441
#        BatchNorm2d-4           [-1, 21, 32, 32]              42
#             Conv2d-5           [-1, 21, 32, 32]           3,969
#        BatchNorm2d-6           [-1, 21, 32, 32]              42
#             Conv2d-7           [-1, 84, 32, 32]           1,764
#        BatchNorm2d-8           [-1, 84, 32, 32]             168
#             Conv2d-9           [-1, 84, 32, 32]          15,876
#       BatchNorm2d-10           [-1, 84, 32, 32]             168
#        Bottleneck-11           [-1, 84, 32, 32]               0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

with open('acc_ResNet50_F.txt','r')as f:
    acc_ResNet50 = f.readlines()
    acc_ResNet50 = [i.replace('\n','') for i in acc_ResNet50]
    acc_ResNet50 = np.array(acc_ResNet50,dtype=float)

plt.figure()
plt.plot(acc_ResNet50,label='ResNet-50-G')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
