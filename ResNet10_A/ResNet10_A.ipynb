# %%
# !python main.py
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 40, 32, 32]           1,080
#        BatchNorm2d-2           [-1, 40, 32, 32]              80
#             Conv2d-3           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-4           [-1, 40, 32, 32]              80
#             Conv2d-5           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-6           [-1, 40, 32, 32]              80
#         BasicBlock-7           [-1, 40, 32, 32]               0
#             Conv2d-8           [-1, 80, 16, 16]          28,800
#        BatchNorm2d-9           [-1, 80, 16, 16]             160
#            Conv2d-10           [-1, 80, 16, 16]          57,600
#       BatchNorm2d-11           [-1, 80, 16, 16]             160
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

with open('acc_ResNet10_A.txt','r')as f:
    acc_ResNet10_A = f.readlines()
    acc_ResNet10_A = [i.replace('\n','') for i in acc_ResNet10_A]
    acc_ResNet10_A = np.array(acc_ResNet10_A,dtype=float)

plt.figure()
plt.plot(acc_ResNet10_A,label='ResNet-10-A')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
