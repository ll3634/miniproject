# %%
# !python main.py
# Out:
# ==> Preparing data..
# ...
# 100%|██████████████████████| 170498071/170498071 [00:01<00:00, 102287775.64it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 15, 32, 32]             405
#        BatchNorm2d-2           [-1, 15, 32, 32]              30
#             Conv2d-3           [-1, 15, 32, 32]             225
#        BatchNorm2d-4           [-1, 15, 32, 32]              30
#             Conv2d-5           [-1, 15, 32, 32]           2,025
#        BatchNorm2d-6           [-1, 15, 32, 32]              30
#             Conv2d-7           [-1, 60, 32, 32]             900
#        BatchNorm2d-8           [-1, 60, 32, 32]             120
#             Conv2d-9           [-1, 60, 32, 32]           8,100
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

with open('acc_ResNet50_B.txt','r')as f:
    acc_ResNet50_B = f.readlines()
    acc_ResNet50_B = [i.replace('\n','') for i in acc_ResNet50_B]
    acc_ResNet50_B = np.array(acc_ResNet50_B,dtype=float)

plt.figure()
plt.plot(acc_ResNet50_B,label='ResNet-50-B')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
