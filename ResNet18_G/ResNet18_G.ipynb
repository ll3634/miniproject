# %%
# !python main.py
# Out:
# ==> Preparing data..
# ...
# 100%|██████████████████████| 170498071/170498071 [00:01<00:00, 100644174.57it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 40, 32, 32]           1,080
#        BatchNorm2d-2           [-1, 40, 32, 32]              80
#             Conv2d-3           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-4           [-1, 40, 32, 32]              80
#             Conv2d-5           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-6           [-1, 40, 32, 32]              80
#         BasicBlock-7           [-1, 40, 32, 32]               0
#             Conv2d-8           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-9           [-1, 40, 32, 32]              80
# ...

# %%
# !python main_test_acc.py
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 40, 32, 32]           1,080
#        BatchNorm2d-2           [-1, 40, 32, 32]              80
#             Conv2d-3           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-4           [-1, 40, 32, 32]              80
#             Conv2d-5           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-6           [-1, 40, 32, 32]              80
#         BasicBlock-7           [-1, 40, 32, 32]               0
#             Conv2d-8           [-1, 40, 32, 32]          14,400
#        BatchNorm2d-9           [-1, 40, 32, 32]              80
#            Conv2d-10           [-1, 40, 32, 32]          14,400
#       BatchNorm2d-11           [-1, 40, 32, 32]              80
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

with open('acc_ResNet18_G.txt','r')as f:
    acc_ResNet18 = f.readlines()
    acc_ResNet18 = [i.replace('\n','') for i in acc_ResNet18]
    acc_ResNet18 = np.array(acc_ResNet18,dtype=float)

plt.figure()
plt.plot(acc_ResNet18,label='ResNet-18-G')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
